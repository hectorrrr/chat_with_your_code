# %% [markdown]
# <!-- #### <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:white; font-size:180%; text-align:left;padding:3.0px; background: maroon; border-bottom: 8px solid black" > TABLE OF CONTENTS<br><div> -->
#
# ### TABLE OF CONTENTS
# * [IMPORTS](#1)
# * [INTRODUCTION](#2)
# * [Neomodel](#3)

# %% [markdown]
# <!-- <a id="1"></a>
# # <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color: white; font-size:120%; text-align:left;padding:3.0px; background: maroon; border-bottom: 8px solid black" > Imports<br><div> -->
#
# ### Imports

# %%
# With this Neomodel import
import ast
import os
from neomodel import db, config
from dotenv import load_dotenv


# Prompts:
from langchain_core.prompts import (
    PromptTemplate
)


## LLMs:
from langchain_community.vectorstores import Neo4jVector
from langchain_openai import OpenAI
from langchain.embeddings import HuggingFaceEmbeddings

# %% [markdown]
# <!-- <a id="2"></a>
# # <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color: white; font-size:120%; text-align:left;padding:3.0px; background: maroon; border-bottom: 8px solid black" > Neomodel<br><div> -->
#
#
# ### Neomodel
#
#
# In this section we will show how to use neomodel to connect and populate a Neo4J Graph Database. For further defails refer to the documentation: [neomodel](https://neo4j.com/developer-blog/py2neo-end-migration-guide/)

# %% [markdown]
# ## Conection

# %%
_ = load_dotenv()
# Initialize the graph with a specific database
# # Neomodel connection
from neomodel import db
# Using URL - auto-managed
config.DATABASE_NAME = 'graphrag'
db.set_connection(url=f"bolt://neo4j:{os.environ['NEO4J_PASSWORD']}@localhost:7687")

# %% [markdown]
# ## Graph Configuration
#
# In this section we are going to generate the visual folder structure of the folder that we want to map to a Knowledge graph, and from there and using a LLM, we will get an iterable that will, previous edition, serve as an entrypoint to generate the graph.

# %%
folder_structure = """
└── 📁data_preprocessing
    └── 📁feature_engineering
        └── 📁pandas
            └── pandas.py
        └── 📁sklearn
            └── sklearn.py
        └── __init__.py
    └── __init__.py
└── 📁modelling
    └── 📁pytorch
        └── __init__.py
        └── data_loader.py
        └── model.py
        └── trainer.py
    └── 📁tensorflow
        └── __init__.py
        └── trainer.py
    └── 📁transformers
        └── __init__.py
        └── trainer.py
    └── __init__.py
└── 📁visualization
    └── 📁plotly
        └── __init__.py
        └── geospatial_plots.py
        └── machine_learning_evaluation_plots.py
        └── statistical_analysis_plots.py
    └── __init__.py
└── __init__.py
"""


node_definitions = """

class Area(StructuredNode):
    name = StringProperty(unique_index=True)
    contains_subarea = RelationshipTo('SubArea', 'CONTAINS')
    contains_framework = RelationshipTo('Framework', 'CONTAINS')

class SubArea(StructuredNode):
    name = StringProperty(unique_index=True)
    contains_framework = RelationshipTo('Framework', 'CONTAINS')

class Framework(StructuredNode):
    name = StringProperty(unique_index=True)
    contains_class = RelationshipTo('Class', 'CONTAINS')
    contains_function = RelationshipTo('Function', 'CONTAINS')
    """

prompt_template = PromptTemplate.from_template(
    """You are a Graph Database expert tasked to Output a python list. In this case the objective is to create a
      Knowledge graph with NeoModel based in Python programming for Data science, in that sense consider:
        - Area: Nodes labeled as 'Area' representing areas of Data Science, like 'Data Visualization' or 'Data Preprocessing'.
        - SubArea: Nodes labeled as 'SubArea' representing sub-areas within a more general Area.
        - Framework: Nodes labeled as 'Framework' representing frameworks used in data science, corresponding generally to libraries, like Tensorflow, pandas, etc.
      Given that relation you should map following folder structure into nodes (and relations):
      {folder_structure}. 
      
      Those have to be adjusted to the following nodes and relationships:
      {node_definitions}. 
      
      Here you have several examples of how the output should look like:
      [{{
      'label':'Area',
      'name':'data_preprocessing',
      'contains_subarea':['feature_engineering']
      }},
        {{
        'label':'Area',
        'name':'visualization',
        'contains_framework':['plotly']
        }}
    
        ]

      where each node need to have a reference of all relations that is has.
      And so on with all the nodes, so the folder structure is fully mapped.
      Only add the relations of direct childs (folders/files directly under the current one).
      Do not add information (or Nodes) about 'Functions' nor 'Classes', that will be done later.
      Do not add any function/framework that is not present in the folder structure provided."""
)

# %% [markdown]
# ## Chain definition to map folder structure to Nodes

# %%
llm  = OpenAI(max_tokens=-1)
chain = prompt_template | llm

# %%
results = chain.invoke({'folder_structure':folder_structure,'node_definitions': node_definitions})
results
# Out:
# '\n[\n    {\n        "label": "Area",\n        "name": "data_preprocessing",\n        "contains_subarea": [\n            "feature_engineering"\n        ]\n    },\n    {\n        "label": "SubArea",\n        "name": "feature_engineering",\n        "contains_framework": [\n            "pandas",\n            "sklearn"\n        ]\n    },\n    {\n        "label": "Framework",\n        "name": "pandas",\n        "contains_class": [],\n        "contains_function": [\n            "pandas.py"\n        ]\n    },\n    {\n        "label": "Framework",\n        "name": "sklearn",\n        "contains_class": [],\n        "contains_function": [\n            "sklearn.py"\n        ]\n    },\n    {\n        "label": "Area",\n        "name": "modelling",\n        "contains_subarea": [\n            "pytorch",\n            "tensorflow",\n            "transformers"\n        ]\n    },\n    {\n        "label": "SubArea",\n        "name": "pytorch",\n        "contains_framework": [\n            "data_loader",\n            "model",\n            "trainer"\n        ]\n    },\n    {\n        "label": "SubArea",\n        "name": "tensorflow",\n        "contains_framework": [\n            "trainer"\n        ]\n    },\n    {\n        "label": "SubArea",\n        "name": "transformers",\n        "contains_framework": [\n            "trainer"\n        ]\n    },\n    {\n        "label": "Framework",\n        "name": "data_loader",\n        "contains_class": [],\n        "contains_function": [\n            "data_loader.py"\n        ]\n    },\n    {\n        "label": "Framework",\n        "name": "model",\n        "contains_class": [],\n        "contains_function": [\n            "model.py"\n        ]\n    },\n    {\n        "label": "Framework",\n        "name": "trainer",\n        "contains_class": [],\n        "contains_function": [\n            "trainer.py"\n        ]\n    },\n    {\n        "label": "Framework",\n        "name": "trainer",\n        "contains_class": [],\n        "contains_function": [\n            "trainer.py"\n        ]\n    },\n    {\n        "label": "Framework",\n        "name": "trainer",\n        "contains_class": [],\n        "contains_function": [\n            "trainer.py"\n        ]\n    },\n    {\n        "label": "Area",\n        "name": "visualization",\n        "contains_framework": [\n            "plotly"\n        ]\n    },\n    {\n        "label": "SubArea",\n        "name": "plotly",\n        "contains_framework": [\n            "geospatial_plots",\n            "machine_learning_evaluation_plots",\n            "statistical_analysis_plots"\n        ]\n    },\n    {\n        "label": "Framework",\n        "name": "geospatial_plots",\n        "contains_class": [],\n        "contains_function": [\n            "geospatial_plots.py"\n        ]\n    },\n    {\n        "label": "Framework",\n        "name": "machine_learning_evaluation_plots",\n        "contains_class": [],\n        "contains_function": [\n            "machine_learning_evaluation_plots.py"\n        ]\n    },\n    {\n        "label": "Framework",\n        "name": "statistical_analysis_plots",\n        "contains_class": [],\n        "contains_function": [\n            "statistical_analysis_plots.py"\n        ]\n    }\n]'

# %%
parsed_list = ast.literal_eval(results)
parsed_list
# Out:
# [{'label': 'Area',
#   'name': 'data_preprocessing',
#   'contains_subarea': ['feature_engineering']},
#  {'label': 'SubArea',
#   'name': 'feature_engineering',
#   'contains_framework': ['pandas', 'sklearn']},
#  {'label': 'Framework',
#   'name': 'pandas',
#   'contains_class': [],
#   'contains_function': ['pandas.py']},
#  {'label': 'Framework',
#   'name': 'sklearn',
#   'contains_class': [],
#   'contains_function': ['sklearn.py']},
#  {'label': 'Area',
#   'name': 'modelling',
#   'contains_subarea': ['pytorch', 'tensorflow', 'transformers']},
#  {'label': 'SubArea',
#   'name': 'pytorch',
#   'contains_framework': ['data_loader', 'model', 'trainer']},
#  {'label': 'SubArea', 'name': 'tensorflow', 'contains_framework': ['trainer']},
#  {'label': 'SubArea',
#   'name': 'transformers',
#   'contains_framework': ['trainer']},
#  {'label': 'Framework',
#   'name': 'data_loader',
#   'contains_class': [],
#   'contains_function': ['data_loader.py']},
#  {'label': 'Framework',
#   'name': 'model',
#   'contains_class': [],
#   'contains_function': ['model.py']},
#  {'label': 'Framework',
#   'name': 'trainer',
#   'contains_class': [],
#   'contains_function': ['trainer.py']},
#  {'label': 'Framework',
#   'name': 'trainer',
#   'contains_class': [],
#   'contains_function': ['trainer.py']},
#  {'label': 'Framework',
#   'name': 'trainer',
#   'contains_class': [],
#   'contains_function': ['trainer.py']},
#  {'label': 'Area', 'name': 'visualization', 'contains_framework': ['plotly']},
#  {'label': 'SubArea',
#   'name': 'plotly',
#   'contains_framework': ['geospatial_plots',
#    'machine_learning_evaluation_plots',
#    'statistical_analysis_plots']},
#  {'label': 'Framework',
#   'name': 'geospatial_plots',
#   'contains_class': [],
#   'contains_function': ['geospatial_plots.py']},
#  {'label': 'Framework',
#   'name': 'machine_learning_evaluation_plots',
#   'contains_class': [],
#   'contains_function': ['machine_learning_evaluation_plots.py']},
#  {'label': 'Framework',
#   'name': 'statistical_analysis_plots',
#   'contains_class': [],
#   'contains_function': ['statistical_analysis_plots.py']}]

# %% [markdown]
# ### There are still many improvements to do to this prompt so we automatically map the folder structure into Nodes/relationships.
# GPT4-turbo could be used to this purpose, right now we will just modify the output manually to complete the showcase

# %%
nodes_relationships = [
    {
        'label': 'Area',
        'name': 'data_preprocessing',
        'relationships': {
            'contains_subarea': ['feature_engineering']
        }
    },
    {
        'label': 'SubArea',
        'name': 'feature_engineering',
        'relationships': {
            'contains_framework': ['pandas', 'sklearn']
        }
    },
    {
        'label': 'Framework',
        'name': 'pandas'
    },
    {
        'label': 'Framework',
        'name': 'sklearn'
    },
    {
        'label': 'Area',
        'name': 'modelling',
        'relationships': {
            'contains_framework': ['pytorch', 'tensorflow', 'transformers']
        }
    },
    {
        'label': 'Framework',
        'name': 'pytorch'
    },
    {   
        'label': 'Framework',
        'name': 'tensorflow'
            
    },
    {
        'label': 'Framework',
        'name': 'transformers'
    },
    {
        'label': 'Area',
        'name': 'visualization',
        'relationships': {
            'contains_framework': ['plotly']
        }
    },
    {
        'label': 'Framework',
        'name': 'plotly'
    }
    ]

# %%
from parse_directory_to_KT.graph_generator import create_graph_for_directory

create_graph_for_directory(db=db, base_path="../../data_science_repo", nodes_relationships=nodes_relationships)
# Out:
# Executing query for node creation: MERGE (n:Area {name: $name}) RETURN n
# Created node: Area - data_preprocessing
# Runned query---> MERGE (n:Area name: data_preprocessing) RETURN n
# Executing query for node creation: MERGE (n:SubArea {name: $name}) RETURN n
# Created node: SubArea - feature_engineering
# Runned query---> MERGE (n:SubArea name: feature_engineering) RETURN n
# Executing query for node creation: MERGE (n:Framework {name: $name}) RETURN n
# Created node: Framework - pandas
# Runned query---> MERGE (n:Framework name: pandas) RETURN n
# Executing query for function node creation:
#                         MERGE (f:Function {name: $name})
#                         ON CREATE SET f.description = $description, f.code = $code, f.file_path = $file_path
#                         RETURN f
#
# Created Function node: remove_outliers with file path data_preprocessing\feature_engineering\pandas\pandas.py
# Query--->
#                         MERGE (f:Function name:remove_outliers)
#                         ON CREATE SET f.description = $description, f.code = $code, f.file_path = $file_path
#                         RETURN f
#
# Executing query for function node creation:
#                         MERGE (f:Function {name: $name})
#                         ON CREATE SET f.description = $description, f.code = $code, f.file_path = $file_path
#                         RETURN f
#
# Created Function node: encode_categorical with file path data_preprocessing\feature_engineering\pandas\pandas.py
# Query--->
#                         MERGE (f:Function name:encode_categorical)
#                         ON CREATE SET f.description = $description, f.code = $code, f.file_path = $file_path
#                         RETURN f
#
# Executing query for function node creation:
#                         MERGE (f:Function {name: $name})
#                         ON CREATE SET f.description = $description, f.code = $code, f.file_path = $file_path
#                         RETURN f
#
# Created Function node: extract_datetime_features with file path data_preprocessing\feature_engineering\pandas\pandas.py
# Query--->
#                         MERGE (f:Function name:extract_datetime_features)
#                         ON CREATE SET f.description = $description, f.code = $code, f.file_path = $file_path
#                         RETURN f
#
# Executing query for node creation: MERGE (n:Framework {name: $name}) RETURN n
# Created node: Framework - sklearn
# Runned query---> MERGE (n:Framework name: sklearn) RETURN n
# Executing query for function node creation:
#                         MERGE (f:Function {name: $name})
#                         ON CREATE SET f.description = $description, f.code = $code, f.file_path = $file_path
#                         RETURN f
#
# Created Function node: scale_features with file path data_preprocessing\feature_engineering\sklearn\sklearn.py
# Query--->
#                         MERGE (f:Function name:scale_features)
#                         ON CREATE SET f.description = $description, f.code = $code, f.file_path = $file_path
#                         RETURN f
#
# Executing query for function node creation:
#                         MERGE (f:Function {name: $name})
#                         ON CREATE SET f.description = $description, f.code = $code, f.file_path = $file_path
#                         RETURN f
#
# Created Function node: create_polynomial_features with file path data_preprocessing\feature_engineering\sklearn\sklearn.py
# Query--->
#                         MERGE (f:Function name:create_polynomial_features)
#                         ON CREATE SET f.description = $description, f.code = $code, f.file_path = $file_path
#                         RETURN f
#
# Executing query for function node creation:
#                         MERGE (f:Function {name: $name})
#                         ON CREATE SET f.description = $description, f.code = $code, f.file_path = $file_path
#                         RETURN f
#
# Created Function node: vectorize_text with file path data_preprocessing\feature_engineering\sklearn\sklearn.py
# Query--->
#                         MERGE (f:Function name:vectorize_text)
#                         ON CREATE SET f.description = $description, f.code = $code, f.file_path = $file_path
#                         RETURN f
#
# Executing query for node creation: MERGE (n:Area {name: $name}) RETURN n
# Created node: Area - modelling
# Runned query---> MERGE (n:Area name: modelling) RETURN n
# Executing query for node creation: MERGE (n:Framework {name: $name}) RETURN n
# Created node: Framework - pytorch
# Runned query---> MERGE (n:Framework name: pytorch) RETURN n
# Executing query for class node creation:
#                         MERGE (c:Class {name: $name})
#                         ON CREATE SET c.description = $description, c.code = $code, c.file_path = $file_path
#                         RETURN c
#
# Created Class node: SimpleDataset with file path modelling\pytorch\data_loader.py
# Runned query--->
#                                         MERGE (c:Class name:SimpleDataset)
#                                         ON CREATE SET c.description = $description, c.code = $code, c.file_path = $file_path
#                                         RETURN c
#
# Executing query for class node creation:
#                         MERGE (c:Class {name: $name})
#                         ON CREATE SET c.description = $description, c.code = $code, c.file_path = $file_path
#                         RETURN c
#
# Created Class node: SimpleClassifier with file path modelling\pytorch\model.py
# Runned query--->
#                                         MERGE (c:Class name:SimpleClassifier)
#                                         ON CREATE SET c.description = $description, c.code = $code, c.file_path = $file_path
#                                         RETURN c
#
# Executing query for class node creation:
#                         MERGE (c:Class {name: $name})
#                         ON CREATE SET c.description = $description, c.code = $code, c.file_path = $file_path
#                         RETURN c
#
# Created Class node: Trainer with file path modelling\pytorch\trainer.py
# Runned query--->
#                                         MERGE (c:Class name:Trainer)
#                                         ON CREATE SET c.description = $description, c.code = $code, c.file_path = $file_path
#                                         RETURN c
#
# Executing query for node creation: MERGE (n:Framework {name: $name}) RETURN n
# Created node: Framework - tensorflow
# Runned query---> MERGE (n:Framework name: tensorflow) RETURN n
# Executing query for class node creation:
#                         MERGE (c:Class {name: $name})
#                         ON CREATE SET c.description = $description, c.code = $code, c.file_path = $file_path
#                         RETURN c
#
# Created Class node: TextClassificationModelTF with file path modelling\tensorflow\trainer.py
# Runned query--->
#                                         MERGE (c:Class name:TextClassificationModelTF)
#                                         ON CREATE SET c.description = $description, c.code = $code, c.file_path = $file_path
#                                         RETURN c
#
# Executing query for node creation: MERGE (n:Framework {name: $name}) RETURN n
# Created node: Framework - transformers
# Runned query---> MERGE (n:Framework name: transformers) RETURN n
# Executing query for class node creation:
#                         MERGE (c:Class {name: $name})
#                         ON CREATE SET c.description = $description, c.code = $code, c.file_path = $file_path
#                         RETURN c
#
# Created Class node: TextClassificationModel with file path modelling\transformers\trainer.py
# Runned query--->
#                                         MERGE (c:Class name:TextClassificationModel)
#                                         ON CREATE SET c.description = $description, c.code = $code, c.file_path = $file_path
#                                         RETURN c
#
# Executing query for node creation: MERGE (n:Area {name: $name}) RETURN n
# Created node: Area - visualization
# Runned query---> MERGE (n:Area name: visualization) RETURN n
# Executing query for node creation: MERGE (n:Framework {name: $name}) RETURN n
# Created node: Framework - plotly
# Runned query---> MERGE (n:Framework name: plotly) RETURN n
# Executing query for function node creation:
#                         MERGE (f:Function {name: $name})
#                         ON CREATE SET f.description = $description, f.code = $code, f.file_path = $file_path
#                         RETURN f
#
# Created Function node: plot_confusion_matrix with file path visualization\plotly\machine_learning_evaluation_plots.py
# Query--->
#                         MERGE (f:Function name:plot_confusion_matrix)
#                         ON CREATE SET f.description = $description, f.code = $code, f.file_path = $file_path
#                         RETURN f
#
# Executing query for function node creation:
#                         MERGE (f:Function {name: $name})
#                         ON CREATE SET f.description = $description, f.code = $code, f.file_path = $file_path
#                         RETURN f
#
# Created Function node: violin_plot with file path visualization\plotly\statistical_analysis_plots.py
# Query--->
#                         MERGE (f:Function name:violin_plot)
#                         ON CREATE SET f.description = $description, f.code = $code, f.file_path = $file_path
#                         RETURN f
#
# Executing relationship query: MATCH (p:Area {name: $parent_name}), (t:SubArea {name: $target_name}) MERGE (p)-[:CONTAINS_SUBAREA]->(t)
# Created relationship: Area - data_preprocessing -> CONTAINS_SUBAREA -> SubArea - feature_engineering
# With query---> MATCH (p:Area name: data_preprocessing), (t:SubArea name:feature_engineering)
# Executing relationship query: MATCH (p:SubArea {name: $parent_name}), (t:Framework {name: $target_name}) MERGE (p)-[:CONTAINS_FRAMEWORK]->(t)
# Created relationship: SubArea - feature_engineering -> CONTAINS_FRAMEWORK -> Framework - pandas
# With query---> MATCH (p:SubArea name: feature_engineering), (t:Framework name:pandas)
# Executing relationship query: MATCH (p:SubArea {name: $parent_name}), (t:Framework {name: $target_name}) MERGE (p)-[:CONTAINS_FRAMEWORK]->(t)
# Created relationship: SubArea - feature_engineering -> CONTAINS_FRAMEWORK -> Framework - sklearn
# With query---> MATCH (p:SubArea name: feature_engineering), (t:Framework name:sklearn)
# Executing relationship query: MATCH (p:Area {name: $parent_name}), (t:Framework {name: $target_name}) MERGE (p)-[:CONTAINS_FRAMEWORK]->(t)
# Created relationship: Area - modelling -> CONTAINS_FRAMEWORK -> Framework - pytorch
# With query---> MATCH (p:Area name: modelling), (t:Framework name:pytorch)
# Executing relationship query: MATCH (p:Area {name: $parent_name}), (t:Framework {name: $target_name}) MERGE (p)-[:CONTAINS_FRAMEWORK]->(t)
# Created relationship: Area - modelling -> CONTAINS_FRAMEWORK -> Framework - tensorflow
# With query---> MATCH (p:Area name: modelling), (t:Framework name:tensorflow)
# Executing relationship query: MATCH (p:Area {name: $parent_name}), (t:Framework {name: $target_name}) MERGE (p)-[:CONTAINS_FRAMEWORK]->(t)
# Created relationship: Area - modelling -> CONTAINS_FRAMEWORK -> Framework - transformers
# With query---> MATCH (p:Area name: modelling), (t:Framework name:transformers)
# Executing relationship query: MATCH (p:Area {name: $parent_name}), (t:Framework {name: $target_name}) MERGE (p)-[:CONTAINS_FRAMEWORK]->(t)
# Created relationship: Area - visualization -> CONTAINS_FRAMEWORK -> Framework - plotly
# With query---> MATCH (p:Area name: visualization), (t:Framework name:plotly)
# Executing function relationship query: MATCH (p:Framework {name: $parent_name}), (f:Function {name: $func_name}) MERGE (p)-[:CONTAINS_FUNCTION]->(f)
# Created relationship: Framework - pandas -> Function remove_outliers
# Executing function relationship query: MATCH (p:Framework {name: $parent_name}), (f:Function {name: $func_name}) MERGE (p)-[:CONTAINS_FUNCTION]->(f)
# Created relationship: Framework - pandas -> Function encode_categorical
# Executing function relationship query: MATCH (p:Framework {name: $parent_name}), (f:Function {name: $func_name}) MERGE (p)-[:CONTAINS_FUNCTION]->(f)
# Created relationship: Framework - pandas -> Function extract_datetime_features
# Executing function relationship query: MATCH (p:Framework {name: $parent_name}), (f:Function {name: $func_name}) MERGE (p)-[:CONTAINS_FUNCTION]->(f)
# Created relationship: Framework - sklearn -> Function scale_features
# Executing function relationship query: MATCH (p:Framework {name: $parent_name}), (f:Function {name: $func_name}) MERGE (p)-[:CONTAINS_FUNCTION]->(f)
# Created relationship: Framework - sklearn -> Function create_polynomial_features
# Executing function relationship query: MATCH (p:Framework {name: $parent_name}), (f:Function {name: $func_name}) MERGE (p)-[:CONTAINS_FUNCTION]->(f)
# Created relationship: Framework - sklearn -> Function vectorize_text
# Executing class relationship query: MATCH (p:Framework {name: $parent_name}), (c:Class {name: $class_name}) MERGE (p)-[:CONTAINS_CLASS]->(c)
# Created relationship: Framework - pytorch -> Class SimpleDataset
# Executing class relationship query: MATCH (p:Framework {name: $parent_name}), (c:Class {name: $class_name}) MERGE (p)-[:CONTAINS_CLASS]->(c)
# Created relationship: Framework - pytorch -> Class SimpleClassifier
# Executing class relationship query: MATCH (p:Framework {name: $parent_name}), (c:Class {name: $class_name}) MERGE (p)-[:CONTAINS_CLASS]->(c)
# Created relationship: Framework - pytorch -> Class Trainer
# Executing class relationship query: MATCH (p:Framework {name: $parent_name}), (c:Class {name: $class_name}) MERGE (p)-[:CONTAINS_CLASS]->(c)
# Created relationship: Framework - tensorflow -> Class TextClassificationModelTF
# Executing class relationship query: MATCH (p:Framework {name: $parent_name}), (c:Class {name: $class_name}) MERGE (p)-[:CONTAINS_CLASS]->(c)
# Created relationship: Framework - transformers -> Class TextClassificationModel
# Executing function relationship query: MATCH (p:Framework {name: $parent_name}), (f:Function {name: $func_name}) MERGE (p)-[:CONTAINS_FUNCTION]->(f)
# Created relationship: Framework - plotly -> Function plot_confusion_matrix
# Executing function relationship query: MATCH (p:Framework {name: $parent_name}), (f:Function {name: $func_name}) MERGE (p)-[:CONTAINS_FUNCTION]->(f)
# Created relationship: Framework - plotly -> Function violin_plot

# %% [markdown]
# ## Delete unwanted relations

# %%
db.cypher_query("""
MATCH ()-[r]->()
WHERE NOT type(r) STARTS WITH 'CONTAINS'
DELETE r;
""")
# Out:
# ([], [])

# %% [markdown]
# This will be fixed in next steps, but there are unwanted relations being introduced.

# %% [markdown]
# ## Create a vector database from this index
#
# As we have mentioned during this development, getting exacts results for our use case based only in the entities and generated query is not completely feasible in many cases. Therefore we go for a hybrid approach, were we are going to mix a 'Graph' based search with a semantic (+keywords) search and join the results. This will make our process more robust.

# %%
# We start with this model but may upgrade to more specific and bigger models
model_name = "sentence-transformers/all-MiniLM-L6-v2" # You can specify any sentence-transformer model from the hub
embeddings = HuggingFaceEmbeddings(model_name=model_name)
url = "bolt://localhost:7687"

# We encode the description attribute of the nodes of type (label) function

existing_graph = Neo4jVector.from_existing_graph(
    embedding=embeddings,
    url=url,
    username = os.environ["NEO4J_USERNAME"], 
    password=os.environ["NEO4J_PASSWORD"],
    database="graphrag",
    # index_name="person_index",
    node_label="Function",
    text_node_properties=["description"],
    embedding_node_property="embedding",
    search_type="hybrid",
    keyword_index_name= "keyword"
)
# Out:
# c:\Users\hecto\OneDrive\Escritorio\github_projects\chat_with_your_code\chat_with_code_env\lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
